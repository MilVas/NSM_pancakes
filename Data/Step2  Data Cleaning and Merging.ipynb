# %%
# to be ignored when copying in the main file
import pandas as pd
import requests
import json
import time

#1 to be added

import numpy as np
import datetime
from datetime import *
from dateutil.relativedelta import *
import calendar

# %%
#2 importing Wiki csv

wikidata = pd.read_csv('books_per_view.csv')
Wiki =pd.DataFrame(wikidata)
# change the titles to upper case
Wiki['Page'] = Wiki['Page'].str.upper()

# %%
#3 importing NYTimes
NYTimes = pd.read_csv('result_selectedcategory.csv')
NYT =pd.DataFrame(NYTimes[['rank', 'title','author','date','month_on_list','list']])
pd.set_option('display.max_rows', 100)
#NYT2 = NYT[['rank', 'title','author','date','month_on_list']]

# %%
NYT
# Out:
#       rank                                      title  \
# 0        1                                      ALONE
# 1        2                                  TICK TOCK
# 2        3            THE GIRL WITH THE DRAGON TATTOO
# 3        4                        WATER FOR ELEPHANTS
# 4        5              THE GIRL WHO PLAYED WITH FIRE
# ...    ...                                        ...
# 1940    11  MICHAEL CRICHTON: THE ANDROMEDA EVOLUTION
# 1941    12                        THE FAMILY UPSTAIRS
# 1942    13                               THE DESERTER
# 1943    14                           THE STARLESS SEA
# 1944    15                             THE TESTAMENTS
#
#                                     author        date  month_on_list  \
# 0                             Lisa Gardner  2011-03-01            1.0
# 1     James Patterson and Michael Ledwidge  2011-03-01            2.0
# 2                            Stieg Larsson  2011-03-01            8.0
# 3                               Sara Gruen  2011-03-01            5.0
# 4                            Stieg Larsson  2011-03-01            7.0
# ...                                    ...         ...            ...
# 1940                       Daniel H Wilson  2019-12-01            1.0
# 1941                           Lisa Jewell  2019-12-01            1.0
# 1942       Nelson DeMille and Alex DeMille  2019-12-01            1.0
# 1943                      Erin Morgenstern  2019-12-01            1.0
# 1944                       Margaret Atwood  2019-12-01            3.0
#
#                                    list
# 0     combined-print-and-e-book-fiction
# 1     combined-print-and-e-book-fiction
# 2     combined-print-and-e-book-fiction
# 3     combined-print-and-e-book-fiction
# 4     combined-print-and-e-book-fiction
# ...                                 ...
# 1940  combined-print-and-e-book-fiction
# 1941  combined-print-and-e-book-fiction
# 1942  combined-print-and-e-book-fiction
# 1943  combined-print-and-e-book-fiction
# 1944  combined-print-and-e-book-fiction
#
# [1945 rows x 6 columns]

# %%
#4 Find the number of books in NYT
len(NYT.title.unique())
# Out:
# 1082

# %%
#5 Filtering for  just one category to reduce the number of duplicates
NYT = NYT.loc[NYT['list'] == 'combined-print-and-e-book-fiction']
NYT
# Out:
#       rank                                      title  \
# 0        1                                      ALONE
# 1        2                                  TICK TOCK
# 2        3            THE GIRL WITH THE DRAGON TATTOO
# 3        4                        WATER FOR ELEPHANTS
# 4        5              THE GIRL WHO PLAYED WITH FIRE
# ...    ...                                        ...
# 1940    11  MICHAEL CRICHTON: THE ANDROMEDA EVOLUTION
# 1941    12                        THE FAMILY UPSTAIRS
# 1942    13                               THE DESERTER
# 1943    14                           THE STARLESS SEA
# 1944    15                             THE TESTAMENTS
#
#                                     author        date  month_on_list  \
# 0                             Lisa Gardner  2011-03-01            1.0
# 1     James Patterson and Michael Ledwidge  2011-03-01            2.0
# 2                            Stieg Larsson  2011-03-01            8.0
# 3                               Sara Gruen  2011-03-01            5.0
# 4                            Stieg Larsson  2011-03-01            7.0
# ...                                    ...         ...            ...
# 1940                       Daniel H Wilson  2019-12-01            1.0
# 1941                           Lisa Jewell  2019-12-01            1.0
# 1942       Nelson DeMille and Alex DeMille  2019-12-01            1.0
# 1943                      Erin Morgenstern  2019-12-01            1.0
# 1944                       Margaret Atwood  2019-12-01            3.0
#
#                                    list
# 0     combined-print-and-e-book-fiction
# 1     combined-print-and-e-book-fiction
# 2     combined-print-and-e-book-fiction
# 3     combined-print-and-e-book-fiction
# 4     combined-print-and-e-book-fiction
# ...                                 ...
# 1940  combined-print-and-e-book-fiction
# 1941  combined-print-and-e-book-fiction
# 1942  combined-print-and-e-book-fiction
# 1943  combined-print-and-e-book-fiction
# 1944  combined-print-and-e-book-fiction
#
# [1945 rows x 6 columns]

# %%
#6 Find the number of books in NYT after filtering
len(NYT.title.unique())
# Out:
# 1082

# %%
#7 find duplicates in NYT

DuplicatesNYT = NYT[NYT.duplicated(['title'])]
print("Duplicated Rows are :", DuplicatesNYT[['title','date','month_on_list']], sep='\n')
# Out:
# Duplicated Rows are :
#                                       title        date  month_on_list
# 20                      WATER FOR ELEPHANTS  2011-04-01            3.0
# 25    THE GIRL WHO KICKED THE HORNET’S NEST  2011-04-01            9.0
# 27          THE GIRL WITH THE DRAGON TATTOO  2011-04-01            8.0
# 28            THE GIRL WHO PLAYED WITH FIRE  2011-04-01            7.0
# 29                        CUTTING FOR STONE  2011-04-01            4.0
# ...                                     ...         ...            ...
# 1936                        THE DUTCH HOUSE  2019-12-01            2.0
# 1937                     THE GIVER OF STARS  2019-12-01            2.0
# 1938                          THE INSTITUTE  2019-12-01            3.0
# 1939                     THE 19TH CHRISTMAS  2019-12-01            2.0
# 1944                         THE TESTAMENTS  2019-12-01            3.0
#
# [863 rows x 3 columns]

# %%
#Dealing with duplicated entres## 

#8 Checking the reason for duplication based on one book.

NYT.loc[NYT['title'] == 'IT']
# Out:
#       rank title        author        date  month_on_list  \
# 1541     2    IT  Stephen King  2017-10-01            2.0
# 1558     4    IT  Stephen King  2017-11-01            2.0
# 1906     7    IT  Stephen King  2019-10-01            1.0
#
#                                    list
# 1541  combined-print-and-e-book-fiction
# 1558  combined-print-and-e-book-fiction
# 1906  combined-print-and-e-book-fiction

# %% [markdown]
# Result: The duplication happens becase of different dates the book was placed on the bestsellers list, the duration on the list, and the different rank each placement had.

# %%
#9. Creating a copy of NYT dataset and assigning a new column to store the last month book was on the list. 
NYT_mod1 = NYT.copy()
NYT_mod1['last_month'] = NYT.apply(lambda _: '', axis=1)
NYT_mod1
# Out:
#       rank                                      title  \
# 0        1                                      ALONE
# 1        2                                  TICK TOCK
# 2        3            THE GIRL WITH THE DRAGON TATTOO
# 3        4                        WATER FOR ELEPHANTS
# 4        5              THE GIRL WHO PLAYED WITH FIRE
# ...    ...                                        ...
# 1940    11  MICHAEL CRICHTON: THE ANDROMEDA EVOLUTION
# 1941    12                        THE FAMILY UPSTAIRS
# 1942    13                               THE DESERTER
# 1943    14                           THE STARLESS SEA
# 1944    15                             THE TESTAMENTS
#
#                                     author        date  month_on_list  \
# 0                             Lisa Gardner  2011-03-01            1.0
# 1     James Patterson and Michael Ledwidge  2011-03-01            2.0
# 2                            Stieg Larsson  2011-03-01            8.0
# 3                               Sara Gruen  2011-03-01            5.0
# 4                            Stieg Larsson  2011-03-01            7.0
# ...                                    ...         ...            ...
# 1940                       Daniel H Wilson  2019-12-01            1.0
# 1941                           Lisa Jewell  2019-12-01            1.0
# 1942       Nelson DeMille and Alex DeMille  2019-12-01            1.0
# 1943                      Erin Morgenstern  2019-12-01            1.0
# 1944                       Margaret Atwood  2019-12-01            3.0
#
#                                    list last_month
# 0     combined-print-and-e-book-fiction
# 1     combined-print-and-e-book-fiction
# 2     combined-print-and-e-book-fiction
# 3     combined-print-and-e-book-fiction
# 4     combined-print-and-e-book-fiction
# ...                                 ...        ...
# 1940  combined-print-and-e-book-fiction
# 1941  combined-print-and-e-book-fiction
# 1942  combined-print-and-e-book-fiction
# 1943  combined-print-and-e-book-fiction
# 1944  combined-print-and-e-book-fiction
#
# [1945 rows x 7 columns]

# %%
#10 Calculating End Date
NYT_mod1['date'] = pd.to_datetime(NYT_mod1['date'])
NYT_mod1['last_month'] = pd.to_datetime(NYT_mod1['last_month'])

f = lambda x: x ['date'] + relativedelta(months = int(x['month_on_list']))
NYT_mod1['last_month'] = NYT_mod1.apply(f, axis=1)

NYT_mod1
# Out:
#       rank                                      title  \
# 0        1                                      ALONE
# 1        2                                  TICK TOCK
# 2        3            THE GIRL WITH THE DRAGON TATTOO
# 3        4                        WATER FOR ELEPHANTS
# 4        5              THE GIRL WHO PLAYED WITH FIRE
# ...    ...                                        ...
# 1940    11  MICHAEL CRICHTON: THE ANDROMEDA EVOLUTION
# 1941    12                        THE FAMILY UPSTAIRS
# 1942    13                               THE DESERTER
# 1943    14                           THE STARLESS SEA
# 1944    15                             THE TESTAMENTS
#
#                                     author       date  month_on_list  \
# 0                             Lisa Gardner 2011-03-01            1.0
# 1     James Patterson and Michael Ledwidge 2011-03-01            2.0
# 2                            Stieg Larsson 2011-03-01            8.0
# 3                               Sara Gruen 2011-03-01            5.0
# 4                            Stieg Larsson 2011-03-01            7.0
# ...                                    ...        ...            ...
# 1940                       Daniel H Wilson 2019-12-01            1.0
# 1941                           Lisa Jewell 2019-12-01            1.0
# 1942       Nelson DeMille and Alex DeMille 2019-12-01            1.0
# 1943                      Erin Morgenstern 2019-12-01            1.0
# 1944                       Margaret Atwood 2019-12-01            3.0
#
#                                    list last_month
# 0     combined-print-and-e-book-fiction 2011-04-01
# 1     combined-print-and-e-book-fiction 2011-05-01
# 2     combined-print-and-e-book-fiction 2011-11-01
# 3     combined-print-and-e-book-fiction 2011-08-01
# 4     combined-print-and-e-book-fiction 2011-10-01
# ...                                 ...        ...
# 1940  combined-print-and-e-book-fiction 2020-01-01
# 1941  combined-print-and-e-book-fiction 2020-01-01
# 1942  combined-print-and-e-book-fiction 2020-01-01
# 1943  combined-print-and-e-book-fiction 2020-01-01
# 1944  combined-print-and-e-book-fiction 2020-03-01
#
# [1945 rows x 7 columns]

# %%
#11 Finding the earliest start date and the latest end date
later_end_date = (pd.DataFrame(NYT_mod1.groupby('title')['last_month'].max())).rename(columns = {'last_month':'E_Date'})
earlier_start_date = (pd.DataFrame(NYT_mod1.groupby('title')['date'].min())).rename(columns = {'date':'S_Date'})

# %%
#12 Merging the obtained dates with the main NYT dataset

obtained_dates = later_end_date.merge(earlier_start_date, on = 'title')

NYT_mod2 = NYT_mod1.copy().merge(obtained_dates, on = 'title')

len(NYT_mod2)
# Out:
# 1945

# %%
#13 getting rid of  last_month column

NYT_mod2.head()
NYT_mod2 = NYT_mod2.drop(['last_month'], axis = 1)
NYT_mod2.head()
# Out:
#    rank                            title  \
# 0     1                            ALONE
# 1     2                        TICK TOCK
# 2    11                        TICK TOCK
# 3     3  THE GIRL WITH THE DRAGON TATTOO
# 4     8  THE GIRL WITH THE DRAGON TATTOO
#
#                                  author       date  month_on_list  \
# 0                          Lisa Gardner 2011-03-01            1.0
# 1  James Patterson and Michael Ledwidge 2011-03-01            2.0
# 2  James Patterson and Michael Ledwidge 2011-04-01            2.0
# 3                         Stieg Larsson 2011-03-01            8.0
# 4                         Stieg Larsson 2011-04-01            8.0
#
#                                 list     E_Date     S_Date
# 0  combined-print-and-e-book-fiction 2011-04-01 2011-03-01
# 1  combined-print-and-e-book-fiction 2011-06-01 2011-03-01
# 2  combined-print-and-e-book-fiction 2011-06-01 2011-03-01
# 3  combined-print-and-e-book-fiction 2012-12-01 2011-03-01
# 4  combined-print-and-e-book-fiction 2012-12-01 2011-03-01

# %%
#14 Calculating the average rank of each book to reduce the duplicates and storing it in a table

average_rank = pd.DataFrame(NYT_mod2.groupby('title')['rank'].mean()).rename(columns = {'rank': 'NYT_average_rank'})
len(average_rank)
# Out:
# 1082

# %%
#15 Calculating the average duration of books between the entries for individual books and storing it in a table

average_duration=pd.DataFrame(NYT_mod2.groupby('title')['month_on_list'].mean()).rename(columns = {'month_on_list': 'average_duration'})

len(average_duration)
# Out:
# 1082

# %%
NYT_mod2.head()
# Out:
#    rank                            title  \
# 0     1                            ALONE
# 1     2                        TICK TOCK
# 2    11                        TICK TOCK
# 3     3  THE GIRL WITH THE DRAGON TATTOO
# 4     8  THE GIRL WITH THE DRAGON TATTOO
#
#                                  author       date  month_on_list  \
# 0                          Lisa Gardner 2011-03-01            1.0
# 1  James Patterson and Michael Ledwidge 2011-03-01            2.0
# 2  James Patterson and Michael Ledwidge 2011-04-01            2.0
# 3                         Stieg Larsson 2011-03-01            8.0
# 4                         Stieg Larsson 2011-04-01            8.0
#
#                                 list     E_Date     S_Date
# 0  combined-print-and-e-book-fiction 2011-04-01 2011-03-01
# 1  combined-print-and-e-book-fiction 2011-06-01 2011-03-01
# 2  combined-print-and-e-book-fiction 2011-06-01 2011-03-01
# 3  combined-print-and-e-book-fiction 2012-12-01 2011-03-01
# 4  combined-print-and-e-book-fiction 2012-12-01 2011-03-01

# %%
#16 Dropping original rank, date and month_on_list from the NYT Table

NYT_mod2 =NYT_mod2.drop(columns = ['rank','month_on_list','date'], axis = 1)

len(NYT_mod2.title.unique())
# Out:
# 1082

# %%
len(NYT_mod2)
# Out:
# 1945

# %%
NYT_mod2.loc[NYT_mod2['title'] == 'IT']
# Out:
#      title        author                               list     E_Date  \
# 1581    IT  Stephen King  combined-print-and-e-book-fiction 2019-11-01
# 1582    IT  Stephen King  combined-print-and-e-book-fiction 2019-11-01
# 1583    IT  Stephen King  combined-print-and-e-book-fiction 2019-11-01
#
#          S_Date
# 1581 2017-10-01
# 1582 2017-10-01
# 1583 2017-10-01

# %%
#17 Dropping duplicates
#NYT_mod2.drop_duplicates()
#NYT_mod2= NYT_mod2.loc[~NYT_mod2.index.duplicated(keep='first')]

NYT_mod3 = NYT_mod2.drop_duplicates(['title'], keep='last')

#NYT_mod2.set_index('title', inplace=True)
#NYT_mod2.drop_duplicates(keep=False,inplace=False) 
#NYT_mod2.reset_index(level=0, inplace=True)
# something not right...there should not be duplicates, there should be only one book with this data?!
len(NYT_mod3)
# Out:
# 1082

# %%
#18 Checking a sample

NYT_mod3.loc[NYT_mod3['title'] == 'IT']
# Out:
#      title        author                               list     E_Date  \
# 1583    IT  Stephen King  combined-print-and-e-book-fiction 2019-11-01
#
#          S_Date
# 1583 2017-10-01

# %%
len(NYT_mod3) == len(NYT_mod3.title.unique())
# Out:
# True

# %%
#19 Merging the calculated rank, and number of months  with the NYT data
NYT_mod4 = NYT_mod3.copy().merge(average_rank, on = 'title').merge(average_duration, on = 'title')
len(NYT_mod4)
# Out:
# 1082

# %%
NYT_mod4.head()
# Out:
#                              title                                author  \
# 0                            ALONE                          Lisa Gardner
# 1                        TICK TOCK  James Patterson and Michael Ledwidge
# 2  THE GIRL WITH THE DRAGON TATTOO                         Stieg Larsson
# 3              WATER FOR ELEPHANTS                            Sara Gruen
# 4    THE GIRL WHO PLAYED WITH FIRE                         Stieg Larsson
#
#                                 list     E_Date     S_Date  NYT_average_rank  \
# 0  combined-print-and-e-book-fiction 2011-04-01 2011-03-01          1.000000
# 1  combined-print-and-e-book-fiction 2011-06-01 2011-03-01          6.500000
# 2  combined-print-and-e-book-fiction 2012-12-01 2011-03-01          9.666667
# 3  combined-print-and-e-book-fiction 2012-07-01 2011-03-01          7.666667
# 4  combined-print-and-e-book-fiction 2012-12-01 2011-03-01         12.375000
#
#    average_duration
# 0          1.000000
# 1          2.000000
# 2          7.222222
# 3          3.888889
# 4          6.250000

# %%
#20 Merging the NYT and Wiki

Combo = pd.merge(Wiki, NYT_mod4, left_on='Page', right_on='title')
Combo
# Out:
#    Unnamed: 0  Rank                             Page  Views in millions  \
# 0           1     2             FIFTY SHADES OF GREY                 49
# 1           8     9                A GAME OF THRONES                 27
# 2          13    14              THE HANDMAID'S TALE                 22
# 3          18    17  THE GIRL WITH THE DRAGON TATTOO                 20
# 4          20    21                          INFERNO                 19
# 5          21    22                               IT                 18
#
#                              title            author  \
# 0             FIFTY SHADES OF GREY         E L James
# 1                A GAME OF THRONES  George RR Martin
# 2              THE HANDMAID'S TALE   Margaret Atwood
# 3  THE GIRL WITH THE DRAGON TATTOO     Stieg Larsson
# 4                          INFERNO         Dan Brown
# 5                               IT      Stephen King
#
#                                 list     E_Date     S_Date  NYT_average_rank  \
# 0  combined-print-and-e-book-fiction 2017-01-01 2012-04-01          8.520000
# 1  combined-print-and-e-book-fiction 2021-04-01 2011-05-01         12.000000
# 2  combined-print-and-e-book-fiction 2020-06-01 2017-03-01          9.375000
# 3  combined-print-and-e-book-fiction 2012-12-01 2011-03-01          9.666667
# 4  combined-print-and-e-book-fiction 2016-12-01 2013-06-01          6.750000
# 5  combined-print-and-e-book-fiction 2019-11-01 2017-10-01          4.333333
#
#    average_duration
# 0         18.280000
# 1         21.086957
# 2          8.000000
# 3          7.222222
# 4          3.500000
# 5          1.666667

# %%
#21 dropping the newly created index and Wiki_Title

Combo = Combo.drop(columns = ['Unnamed: 0', 'Page', 'list'], axis = 1)
Combo.columns
# Out:
# Index(['Rank', 'Views in millions', 'title', 'author', 'E_Date', 'S_Date',
#        'NYT_average_rank', 'average_duration'],
#       dtype='object')

# %%
#22. Column renaming
Combo = Combo.rename(columns = {'Rank':'Wiki_Rank', 'Views in millions': 'Wiki_Page_Visits', 
                                    'title': 'Book','author':'Author','E_Date':'To','S_Date':'From', 'NYT_average_rank':'NYT_Rank(avg)', 'average_duration':'Months_on_NYT_list(avg)'})
Combo
# Out:
#    Wiki_Rank  Wiki_Page_Visits                             Book  \
# 0          2                49             FIFTY SHADES OF GREY
# 1          9                27                A GAME OF THRONES
# 2         14                22              THE HANDMAID'S TALE
# 3         17                20  THE GIRL WITH THE DRAGON TATTOO
# 4         21                19                          INFERNO
# 5         22                18                               IT
#
#              Author         To       From  NYT_Rank(avg)  \
# 0         E L James 2017-01-01 2012-04-01       8.520000
# 1  George RR Martin 2021-04-01 2011-05-01      12.000000
# 2   Margaret Atwood 2020-06-01 2017-03-01       9.375000
# 3     Stieg Larsson 2012-12-01 2011-03-01       9.666667
# 4         Dan Brown 2016-12-01 2013-06-01       6.750000
# 5      Stephen King 2019-11-01 2017-10-01       4.333333
#
#    Months_on_NYT_list(avg)
# 0                18.280000
# 1                21.086957
# 2                 8.000000
# 3                 7.222222
# 4                 3.500000
# 5                 1.666667

# %%
#23. Column reordering

column_order = ['Book', 'Author','Wiki_Rank', 'NYT_Rank(avg)', 'Months_on_NYT_list(avg)','From','To','Wiki_Page_Visits']
Combo = Combo[column_order]

# %%
Combo
# Out:
#                               Book            Author  Wiki_Rank  \
# 0             FIFTY SHADES OF GREY         E L James          2
# 1                A GAME OF THRONES  George RR Martin          9
# 2              THE HANDMAID'S TALE   Margaret Atwood         14
# 3  THE GIRL WITH THE DRAGON TATTOO     Stieg Larsson         17
# 4                          INFERNO         Dan Brown         21
# 5                               IT      Stephen King         22
#
#    NYT_Rank(avg)  Months_on_NYT_list(avg)       From         To  \
# 0       8.520000                18.280000 2012-04-01 2017-01-01
# 1      12.000000                21.086957 2011-05-01 2021-04-01
# 2       9.375000                 8.000000 2017-03-01 2020-06-01
# 3       9.666667                 7.222222 2011-03-01 2012-12-01
# 4       6.750000                 3.500000 2013-06-01 2016-12-01
# 5       4.333333                 1.666667 2017-10-01 2019-11-01
#
#    Wiki_Page_Visits
# 0                49
# 1                27
# 2                22
# 3                20
# 4                19
# 5                18

# %%
#24 round the numbers in NYT-rank and Months
#Combo.NYT_Rank(avg) = Combo.NYT_Rank(avg).round() did not work...

decimals = 1    
Combo['NYT_Rank(avg)'] = Combo['NYT_Rank(avg)'].apply(lambda x: round(x, decimals))
Combo['Months_on_NYT_list(avg)'] = Combo['Months_on_NYT_list(avg)'].apply(lambda x: round(x, decimals))

# %%
Combo
# Out:
#                               Book            Author  Wiki_Rank  \
# 0             FIFTY SHADES OF GREY         E L James          2
# 1                A GAME OF THRONES  George RR Martin          9
# 2              THE HANDMAID'S TALE   Margaret Atwood         14
# 3  THE GIRL WITH THE DRAGON TATTOO     Stieg Larsson         17
# 4                          INFERNO         Dan Brown         21
# 5                               IT      Stephen King         22
#
#    NYT_Rank(avg)  Months_on_NYT_list(avg)       From         To  \
# 0            8.5                     18.3 2012-04-01 2017-01-01
# 1           12.0                     21.1 2011-05-01 2021-04-01
# 2            9.4                      8.0 2017-03-01 2020-06-01
# 3            9.7                      7.2 2011-03-01 2012-12-01
# 4            6.8                      3.5 2013-06-01 2016-12-01
# 5            4.3                      1.7 2017-10-01 2019-11-01
#
#    Wiki_Page_Visits
# 0                49
# 1                27
# 2                22
# 3                20
# 4                19
# 5                18

# %%
#25 exporting
